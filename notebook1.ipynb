# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

orders = pd.read_excel(r"C:\Users\katar\Desktop\orders.xlsx")
orders['OrderDate'] = pd.to_datetime(orders['OrderDate'])
orders['TotalRevenue'] = orders['UnitsPurchased'] * orders['PricePerUnit']

# initial checks
display(orders.head())
print(orders.info())
print(orders['ProductCategory'].value_counts())

# first chart: revenue by category
orders.groupby('ProductCategory')['TotalRevenue'].sum().plot(kind='bar', figsize=(8,4))
plt.title("Revenue by Product Category")
plt.ylabel("Total Revenue ($)")
plt.tight_layout(); plt.show()
# Out:
#    OrderID CustomerID  Gender  Country ProductCategory  UnitsPurchased  \
# 0     1001       C001  Female      USA     Electronics               2
# 1     1002       C002    Male   Canada      Home Decor               1
# 2     1003       C003  Female      USA         Fitness               3
# 3     1004       C004  Female  Germany     Electronics               1
# 4     1005       C005    Male   France          Beauty               4
#
#    PricePerUnit  OrderDate PaymentMethod  TotalRevenue
# 0        299.99 2025-01-02   Credit Card        599.98
# 1         59.99 2025-01-03        PayPal         59.99
# 2         39.99 2025-01-05    Debit Card        119.97
# 3        499.99 2025-01-06   Credit Card        499.99
# 4         19.99 2025-01-07        PayPal         79.96
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          15 non-null     int64
#  1   CustomerID       15 non-null     object
#  2   Gender           15 non-null     object
#  3   Country          15 non-null     object
#  4   ProductCategory  15 non-null     object
#  5   UnitsPurchased   15 non-null     int64
#  6   PricePerUnit     15 non-null     float64
#  7   OrderDate        15 non-null     datetime64[ns]
#  8   PaymentMethod    15 non-null     object
#  9   TotalRevenue     15 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 1.3+ KB
# None
# ProductCategory
# Electronics    5
# Fitness        4
# Home Decor     3
# Beauty         3
# Name: count, dtype: int64
